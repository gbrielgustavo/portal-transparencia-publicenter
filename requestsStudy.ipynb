# %%
import httpx

# %%
url = 'https://transparencia.lagoaformosa.mg.gov.br/publico/despesaDetalhada?elementosPorPagina=40471&pagina=1&termoBase64=&indAgrupamento=FOR&datInicio=2017-01-01&datFim=2026-07-31&desNatureza=&codAdministracao=1&filtrarApenasCovid=false&numEmpenho='

# %%
response = httpx.get(url)

with open("output.json", 'w', encoding = 'utf-8') as file: file.write(response.text)

# %%
import json
data = json.loads(response.text)

# %%
keys = data['content'][0].keys()
keys
# Out:
# dict_keys(['codDespesaDetalhada', 'nomFornecedor', 'desDocumentoFornecedor', 'numEmpenho', 'numAnoEmpenho', 'vlrEmpenhado', 'vlrLiquidado', 'vlrPago', 'datMovimento', 'datVencimento', 'codOrgao', 'desOrgao', 'codUnidade', 'desUnidade', 'codFuncao', 'desFuncao', 'codSubFuncao', 'desSubFuncao', 'desFonte', 'vlrLiquidoPago', 'desHistoricoLiquido', 'desEmpenhoHistorico', 'codAdministracao', 'desAdministracao', 'codPrograma', 'desPrograma', 'codAcao', 'desAcao', 'desModalidade', 'desLicitacaoEmpenho', 'desProcessoEmpenho', 'desContratoEmpenho', 'desDespesa', 'desDespesaOrcamentaria', 'desServico', 'desClassificacao', 'numLiquidacao', 'numPagamento', 'indCovid', 'numNotaFiscal', 'vlrDescontoInss', 'vlrDescontoIrrf', 'vlrDescontoIss', 'vlrDescontoOutros', 'desAgrupamento', 'datLiquidacao', 'datPagamento', 'datUltimoMovimento', 'licitacaoOutraAdministracao', 'codAdministracaoLicitacaoEmpenho', 'descricao', 'titulo', 'rota', 'chave', 'mostrarLicitacao', 'vlrMovimento', 'totalDesconto', 'desMovimento', 'fornecedorFormatado', 'empenhoFormatado', 'desLicitacaoEmpenhoFormatado', 'vlrEmpenhadoFormatado', 'vlrLiquidadoFormatado', 'desDocumentoFornecedorFormatado', 'desDepesaNaturezaFormatado', 'vlrPagoFormatado'])

# %%
extractedData = [list(keys)]

for i in range(len(data['content'])):
    tempList = []
    for k in keys:
        tempList.append(data['content'][i][k])
    extractedData.append(tempList)

# %%
import csv

with open ('allData.csv', 'w', newline="", encoding='utf-8') as file:
    writer = csv.writer(file, delimiter=';')
    writer.writerows(extractedData)

# %%
# Despesa orçamentária

# Pesquisar despesas:
url = 'https://transparencia.lagoaformosa.mg.gov.br/publico/despesaDetalhada?elementosPorPagina=20&pagina=1&termoBase64=&indAgrupamento=FOR&datInicio=2026-07-01&datFim=2026-07-23&desNatureza=&codAdministracao=1&filtrarApenasCovid=false&numEmpenho='

# Busca por Fornecedor
url = 'https://transparencia.lagoaformosa.mg.gov.br/publico/despesaDetalhada?elementosPorPagina=20&pagina=1&termoBase64=NjIuMTcwLjI4Ni8wMDAxLTAw&indAgrupamento=FOR&datInicio=2026-07-01&datFim=2026-07-31&desNatureza=&codAdministracao=1&filtrarApenasCovid=false&numEmpenho='

# Visualizar detalhes da despesa:
url = 'https://transparencia.lagoaformosa.mg.gov.br/publico/despesaDetalhada/buscarMovimentacao?numEmpenho=004127&numAnoEmpenho=2026&codAdministracao=1'

# Detalhes da licitação / Empenho | Numero e anos vem nos detalhes da despesa
url = 'https://transparencia.lagoaformosa.mg.gov.br/publico/licitacao/buscarResultadoPesquisa?numLicitacao=000009&numAnoLicitacao=2025&codAdministracao=1&numProcesso=000090'

# Descontos do empenho
url = 'https://transparencia.lagoaformosa.mg.gov.br/publico/despesaDetalhada/buscarDescontosEmpenho?numEmpenho=003428&numAnoEmpenho=2026&codAdministracao=1'

# Dados do Contrato | Numero e anos vem nos detalhes da despesa
url = 'https://transparencia.lagoaformosa.mg.gov.br/publico/contrato/buscarResultadoPesquisa?numContrato=0000000000000000068&numAnoContrato=2026&codAdministracao=1'


# Informações do contrato | Codigo do contrato está nos dados do contrato
url = 'https://transparencia.lagoaformosa.mg.gov.br/publico/contrato/648'

# Obter documentos armazenados | O numero do documento está nas Informações do contrato
url = 'https://transparencia.lagoaformosa.mg.gov.br/publico/contrato/downloadArquivoBanco/2164'

# Detalhar licitação
url = 'https://transparencia.lagoaformosa.mg.gov.br/publico/licitacao/buscarResultadoPesquisa?numLicitacao=000009&numAnoLicitacao=2025&codAdministracao=1&numProcesso=000090'

# Informações da licitação | Numero está nos detalhes da licitação
url = 'https://transparencia.lagoaformosa.mg.gov.br/publico/licitacao/503'

# %%
import pandas as pd

df = pd.DataFrame(extractedData[1:], columns=extractedData[0])
df
# Out:
#                                           desAgrupamento nomFornecedor  \
# 0      59.371.293/0001-66 - 59 371 293 MAX BRAGA DA S...          None
# 1                   03.574.171/0001-12 - MANG PATOS LTDA          None
# 2             66.717.719/0001-56 - PATOS HIDRAULICA LTDA          None
# 3      59.371.293/0001-66 - 59 371 293 MAX BRAGA DA S...          None
# 4      59.371.293/0001-66 - 59 371 293 MAX BRAGA DA S...          None
# ...                                                  ...           ...
# 40466          ***.320.576-** - MARCELO DOMINGUES VIEIRA          None
# 40467         ***.271.246-** - LAURO RIBEIRO DE MENDONÇA          None
# 40468  ***.619.266-** - SEBASTIAO ANSELMO GOMES DOS S...          None
# 40469       ***.872.446-** - ADAN CARLOS REZENDE RIBEIRO          None
# 40470         ***.444.296-** - ONIVAL BERNARDES DA COSTA          None
#
#       desDocumentoFornecedor numEmpenho  numAnoEmpenho  vlrEmpenhado  \
# 0         59.371.293/0001-66     004127           2026        180.00
# 1         03.574.171/0001-12     004126           2026         96.00
# 2         66.717.719/0001-56     004125           2026       1800.00
# 3         59.371.293/0001-66     004124           2026        100.00
# 4         59.371.293/0001-66     004123           2026        180.00
# ...                      ...        ...            ...           ...
# 40466         034.320.576-95     000005           2021        189.00
# 40467         038.271.246-38     000004           2021         94.50
# 40468         008.619.266-33     000003           2021         68.72
# 40469         091.872.446-59     000002           2021         94.50
# 40470         578.444.296-15     000001           2021         94.50
#
#        vlrLiquidado  vlrPago datMovimento datVencimento desModalidade
# 0              0.00     0.00         None          None    Dispensada
# 1              0.00     0.00         None          None    Dispensada
# 2              0.00     0.00         None          None    Dispensada
# 3              0.00     0.00         None          None    Dispensada
# 4              0.00     0.00         None          None    Dispensada
# ...             ...      ...          ...           ...           ...
# 40466        189.00   189.00         None          None    Dispensada
# 40467         94.50    94.50         None          None    Dispensada
# 40468         68.72    68.72         None          None    Dispensada
# 40469         94.50    94.50         None          None    Dispensada
# 40470         94.50    94.50         None          None    Dispensada
#
# [40471 rows x 11 columns]

# %%
# df['nomFornecedor','datMovimento','datVencimento' ] = df['nomFornecedor','datMovimento','datVencimento' ].astype(str)
for i in ['nomFornecedor','datMovimento','datVencimento' ]:
    df[i] = df[i].astype(str)

# %%
df2 = df.dropna()

# %%
df
# Out:
#                                           desAgrupamento nomFornecedor  \
# 0      59.371.293/0001-66 - 59 371 293 MAX BRAGA DA S...           NaN
# 1                   03.574.171/0001-12 - MANG PATOS LTDA           NaN
# 2             66.717.719/0001-56 - PATOS HIDRAULICA LTDA           NaN
# 3      59.371.293/0001-66 - 59 371 293 MAX BRAGA DA S...           NaN
# 4      59.371.293/0001-66 - 59 371 293 MAX BRAGA DA S...           NaN
# ...                                                  ...           ...
# 40466          ***.320.576-** - MARCELO DOMINGUES VIEIRA           NaN
# 40467         ***.271.246-** - LAURO RIBEIRO DE MENDONÇA           NaN
# 40468  ***.619.266-** - SEBASTIAO ANSELMO GOMES DOS S...           NaN
# 40469       ***.872.446-** - ADAN CARLOS REZENDE RIBEIRO           NaN
# 40470         ***.444.296-** - ONIVAL BERNARDES DA COSTA           NaN
#
#       desDocumentoFornecedor numEmpenho  numAnoEmpenho  vlrEmpenhado  \
# 0         59.371.293/0001-66     004127           2026        180.00
# 1         03.574.171/0001-12     004126           2026         96.00
# 2         66.717.719/0001-56     004125           2026       1800.00
# 3         59.371.293/0001-66     004124           2026        100.00
# 4         59.371.293/0001-66     004123           2026        180.00
# ...                      ...        ...            ...           ...
# 40466         034.320.576-95     000005           2021        189.00
# 40467         038.271.246-38     000004           2021         94.50
# 40468         008.619.266-33     000003           2021         68.72
# 40469         091.872.446-59     000002           2021         94.50
# 40470         578.444.296-15     000001           2021         94.50
#
#        vlrLiquidado  vlrPago datMovimento datVencimento desModalidade
# 0              0.00     0.00          NaN           NaN    Dispensada
# 1              0.00     0.00          NaN           NaN    Dispensada
# 2              0.00     0.00          NaN           NaN    Dispensada
# 3              0.00     0.00          NaN           NaN    Dispensada
# 4              0.00     0.00          NaN           NaN    Dispensada
# ...             ...      ...          ...           ...           ...
# 40466        189.00   189.00          NaN           NaN    Dispensada
# 40467         94.50    94.50          NaN           NaN    Dispensada
# 40468         68.72    68.72          NaN           NaN    Dispensada
# 40469         94.50    94.50          NaN           NaN    Dispensada
# 40470         94.50    94.50          NaN           NaN    Dispensada
#
# [40471 rows x 11 columns]

# %%
import pantab

pantab.frame_to_hyper(df, "lagoa2.hyper", table="Lagoa")
